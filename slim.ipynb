# %%
# %pip install llmware
# Out:
# Requirement already satisfied: llmware in ./myenv/lib/python3.11/site-packages (0.2.2)
# Requirement already satisfied: ai21==1.0.3 in ./myenv/lib/python3.11/site-packages (from llmware) (1.0.3)
# Requirement already satisfied: anthropic==0.3.11 in ./myenv/lib/python3.11/site-packages (from llmware) (0.3.11)
# Requirement already satisfied: beautifulsoup4==4.11.1 in ./myenv/lib/python3.11/site-packages (from llmware) (4.11.1)
# Requirement already satisfied: boto3==1.24.53 in ./myenv/lib/python3.11/site-packages (from llmware) (1.24.53)
# Requirement already satisfied: cohere==4.1.3 in ./myenv/lib/python3.11/site-packages (from llmware) (4.1.3)
# Requirement already satisfied: datasets==2.15.0 in ./myenv/lib/python3.11/site-packages (from llmware) (2.15.0)
# Requirement already satisfied: faiss-cpu==1.7.4 in ./myenv/lib/python3.11/site-packages (from llmware) (1.7.4)
# Requirement already satisfied: huggingface-hub==0.19.4 in ./myenv/lib/python3.11/site-packages (from llmware) (0.19.4)
# Requirement already satisfied: lxml==4.9.3 in ./myenv/lib/python3.11/site-packages (from llmware) (4.9.3)
# Requirement already satisfied: numpy>=1.23.2 in ./myenv/lib/python3.11/site-packages (from llmware) (1.26.4)
# Requirement already satisfied: openai==0.27.7 in ./myenv/lib/python3.11/site-packages (from llmware) (0.27.7)
# Requirement already satisfied: pdf2image==1.16.0 in ./myenv/lib/python3.11/site-packages (from llmware) (1.16.0)
# Requirement already satisfied: pymilvus==2.3.0 in ./myenv/lib/python3.11/site-packages (from llmware) (2.3.0)
# Requirement already satisfied: pymongo==4.5.0 in ./myenv/lib/python3.11/site-packages (from llmware) (4.5.0)
# Requirement already satisfied: pytesseract==0.3.10 in ./myenv/lib/python3.11/site-packages (from llmware) (0.3.10)
# Requirement already satisfied: sentence-transformers==2.2.2 in ./myenv/lib/python3.11/site-packages (from llmware) (2.2.2)
# Requirement already satisfied: tabulate==0.9.0 in ./myenv/lib/python3.11/site-packages (from llmware) (0.9.0)
# Requirement already satisfied: tokenizers>=0.15.0 in ./myenv/lib/python3.11/site-packages (from llmware) (0.15.2)
# Requirement already satisfied: torch>=1.13.1 in ./myenv/lib/python3.11/site-packages (from llmware) (2.2.0)
# Requirement already satisfied: transformers>=4.36.0 in ./myenv/lib/python3.11/site-packages (from llmware) (4.37.2)
# Requirement already satisfied: Werkzeug==3.0.1 in ./myenv/lib/python3.11/site-packages (from llmware) (3.0.1)
# Requirement already satisfied: word2number==1.1 in ./myenv/lib/python3.11/site-packages (from llmware) (1.1)
# Requirement already satisfied: Wikipedia-API==0.6.0 in ./myenv/lib/python3.11/site-packages (from llmware) (0.6.0)
# Requirement already satisfied: yfinance==0.2.28 in ./myenv/lib/python3.11/site-packages (from llmware) (0.2.28)
# Requirement already satisfied: psycopg-binary==3.1.17 in ./myenv/lib/python3.11/site-packages (from llmware) (3.1.17)
# Requirement already satisfied: psycopg==3.1.17 in ./myenv/lib/python3.11/site-packages (from llmware) (3.1.17)
# Requirement already satisfied: pgvector==0.2.4 in ./myenv/lib/python3.11/site-packages (from llmware) (0.2.4)
# Requirement already satisfied: colorama==0.4.6 in ./myenv/lib/python3.11/site-packages (from llmware) (0.4.6)
# Requirement already satisfied: requests in ./myenv/lib/python3.11/site-packages (from ai21==1.0.3->llmware) (2.31.0)
# Requirement already satisfied: anyio<4,>=3.5.0 in ./myenv/lib/python3.11/site-packages (from anthropic==0.3.11->llmware) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./myenv/lib/python3.11/site-packages (from anthropic==0.3.11->llmware) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./myenv/lib/python3.11/site-packages (from anthropic==0.3.11->llmware) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./myenv/lib/python3.11/site-packages (from anthropic==0.3.11->llmware) (2.6.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in ./myenv/lib/python3.11/site-packages (from anthropic==0.3.11->llmware) (4.9.0)
# Requirement already satisfied: soupsieve>1.2 in ./myenv/lib/python3.11/site-packages (from beautifulsoup4==4.11.1->llmware) (2.5)
# Requirement already satisfied: botocore<1.28.0,>=1.27.53 in ./myenv/lib/python3.11/site-packages (from boto3==1.24.53->llmware) (1.27.96)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./myenv/lib/python3.11/site-packages (from boto3==1.24.53->llmware) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in ./myenv/lib/python3.11/site-packages (from boto3==1.24.53->llmware) (0.6.2)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in ./myenv/lib/python3.11/site-packages (from cohere==4.1.3->llmware) (3.9.3)
# Requirement already satisfied: backoff<3.0,>=2.0 in ./myenv/lib/python3.11/site-packages (from cohere==4.1.3->llmware) (2.2.1)
# Requirement already satisfied: pyarrow>=8.0.0 in ./myenv/lib/python3.11/site-packages (from datasets==2.15.0->llmware) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in ./myenv/lib/python3.11/site-packages (from datasets==2.15.0->llmware) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in ./myenv/lib/python3.11/site-packages (from datasets==2.15.0->llmware) (0.3.7)
# Requirement already satisfied: pandas in ./myenv/lib/python3.11/site-packages (from datasets==2.15.0->llmware) (2.2.0)
# Requirement already satisfied: tqdm>=4.62.1 in ./myenv/lib/python3.11/site-packages (from datasets==2.15.0->llmware) (4.66.2)
# Requirement already satisfied: xxhash in ./myenv/lib/python3.11/site-packages (from datasets==2.15.0->llmware) (3.4.1)
# Requirement already satisfied: multiprocess in ./myenv/lib/python3.11/site-packages (from datasets==2.15.0->llmware) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in ./myenv/lib/python3.11/site-packages (from datasets==2.15.0->llmware) (2023.10.0)
# Requirement already satisfied: packaging in ./myenv/lib/python3.11/site-packages (from datasets==2.15.0->llmware) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in ./myenv/lib/python3.11/site-packages (from datasets==2.15.0->llmware) (6.0.1)
# Requirement already satisfied: filelock in ./myenv/lib/python3.11/site-packages (from huggingface-hub==0.19.4->llmware) (3.13.1)
# Requirement already satisfied: pillow in ./myenv/lib/python3.11/site-packages (from pdf2image==1.16.0->llmware) (10.2.0)
# Requirement already satisfied: grpcio<=1.56.0,>=1.49.1 in ./myenv/lib/python3.11/site-packages (from pymilvus==2.3.0->llmware) (1.56.0)
# Requirement already satisfied: protobuf>=3.20.0 in ./myenv/lib/python3.11/site-packages (from pymilvus==2.3.0->llmware) (4.25.3)
# Requirement already satisfied: environs<=9.5.0 in ./myenv/lib/python3.11/site-packages (from pymilvus==2.3.0->llmware) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in ./myenv/lib/python3.11/site-packages (from pymilvus==2.3.0->llmware) (5.9.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./myenv/lib/python3.11/site-packages (from pymongo==4.5.0->llmware) (2.5.0)
# Requirement already satisfied: torchvision in ./myenv/lib/python3.11/site-packages (from sentence-transformers==2.2.2->llmware) (0.17.0)
# Requirement already satisfied: scikit-learn in ./myenv/lib/python3.11/site-packages (from sentence-transformers==2.2.2->llmware) (1.4.0)
# Requirement already satisfied: scipy in ./myenv/lib/python3.11/site-packages (from sentence-transformers==2.2.2->llmware) (1.12.0)
# Requirement already satisfied: nltk in ./myenv/lib/python3.11/site-packages (from sentence-transformers==2.2.2->llmware) (3.8.1)
# Requirement already satisfied: sentencepiece in ./myenv/lib/python3.11/site-packages (from sentence-transformers==2.2.2->llmware) (0.1.99)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./myenv/lib/python3.11/site-packages (from Werkzeug==3.0.1->llmware) (2.1.5)
# Requirement already satisfied: multitasking>=0.0.7 in ./myenv/lib/python3.11/site-packages (from yfinance==0.2.28->llmware) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in ./myenv/lib/python3.11/site-packages (from yfinance==0.2.28->llmware) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in ./myenv/lib/python3.11/site-packages (from yfinance==0.2.28->llmware) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in ./myenv/lib/python3.11/site-packages (from yfinance==0.2.28->llmware) (2.4.0)
# Requirement already satisfied: html5lib>=1.1 in ./myenv/lib/python3.11/site-packages (from yfinance==0.2.28->llmware) (1.1)
# Requirement already satisfied: sympy in ./myenv/lib/python3.11/site-packages (from torch>=1.13.1->llmware) (1.12)
# Requirement already satisfied: networkx in ./myenv/lib/python3.11/site-packages (from torch>=1.13.1->llmware) (3.2.1)
# Requirement already satisfied: jinja2 in ./myenv/lib/python3.11/site-packages (from torch>=1.13.1->llmware) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in ./myenv/lib/python3.11/site-packages (from transformers>=4.36.0->llmware) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in ./myenv/lib/python3.11/site-packages (from transformers>=4.36.0->llmware) (0.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./myenv/lib/python3.11/site-packages (from aiohttp<4.0,>=3.0->cohere==4.1.3->llmware) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./myenv/lib/python3.11/site-packages (from aiohttp<4.0,>=3.0->cohere==4.1.3->llmware) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./myenv/lib/python3.11/site-packages (from aiohttp<4.0,>=3.0->cohere==4.1.3->llmware) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./myenv/lib/python3.11/site-packages (from aiohttp<4.0,>=3.0->cohere==4.1.3->llmware) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./myenv/lib/python3.11/site-packages (from aiohttp<4.0,>=3.0->cohere==4.1.3->llmware) (1.9.4)
# Requirement already satisfied: idna>=2.8 in ./myenv/lib/python3.11/site-packages (from anyio<4,>=3.5.0->anthropic==0.3.11->llmware) (3.6)
# Requirement already satisfied: sniffio>=1.1 in ./myenv/lib/python3.11/site-packages (from anyio<4,>=3.5.0->anthropic==0.3.11->llmware) (1.3.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./myenv/lib/python3.11/site-packages (from botocore<1.28.0,>=1.27.53->boto3==1.24.53->llmware) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in ./myenv/lib/python3.11/site-packages (from botocore<1.28.0,>=1.27.53->boto3==1.24.53->llmware) (1.26.18)
# Requirement already satisfied: marshmallow>=3.0.0 in ./myenv/lib/python3.11/site-packages (from environs<=9.5.0->pymilvus==2.3.0->llmware) (3.20.2)
# Requirement already satisfied: python-dotenv in ./myenv/lib/python3.11/site-packages (from environs<=9.5.0->pymilvus==2.3.0->llmware) (1.0.1)
# Requirement already satisfied: six>=1.9 in ./myenv/lib/python3.11/site-packages (from html5lib>=1.1->yfinance==0.2.28->llmware) (1.16.0)
# Requirement already satisfied: webencodings in ./myenv/lib/python3.11/site-packages (from html5lib>=1.1->yfinance==0.2.28->llmware) (0.5.1)
# Requirement already satisfied: certifi in ./myenv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->anthropic==0.3.11->llmware) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in ./myenv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->anthropic==0.3.11->llmware) (1.0.3)
# Requirement already satisfied: h11<0.15,>=0.13 in ./myenv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic==0.3.11->llmware) (0.14.0)
# Requirement already satisfied: tzdata>=2022.7 in ./myenv/lib/python3.11/site-packages (from pandas->datasets==2.15.0->llmware) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./myenv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->anthropic==0.3.11->llmware) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in ./myenv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->anthropic==0.3.11->llmware) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./myenv/lib/python3.11/site-packages (from requests->ai21==1.0.3->llmware) (3.3.2)
# Requirement already satisfied: click in ./myenv/lib/python3.11/site-packages (from nltk->sentence-transformers==2.2.2->llmware) (8.1.7)
# Requirement already satisfied: joblib in ./myenv/lib/python3.11/site-packages (from nltk->sentence-transformers==2.2.2->llmware) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./myenv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers==2.2.2->llmware) (3.3.0)
# Requirement already satisfied: mpmath>=0.19 in ./myenv/lib/python3.11/site-packages (from sympy->torch>=1.13.1->llmware) (1.3.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from llmware.models import ModelCatalog

ModelCatalog().get_llm_toolkit()
ModelCatalog().tool_test_run("slim-sentiment-tool")
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# config.json: 100%|██████████| 15.8k/15.8k [00:00<00:00, 6.49MB/s]
# .gitattributes: 100%|██████████| 1.57k/1.57k [00:00<00:00, 1.28MB/s]
# README.md: 100%|██████████| 1.68k/1.68k [00:00<00:00, 5.85MB/s]
# slim-ner.gguf: 100%|██████████| 669M/669M [03:07<00:00, 3.56MB/s]
# Fetching 4 files: 100%|██████████| 4/4 [03:09<00:00, 47.31s/it]
# README.md: 100%|██████████| 1.72k/1.72k [00:00<00:00, 6.84MB/s]
# config.json: 100%|██████████| 20.9k/20.9k [00:00<00:00, 21.7MB/s]
#
# .gitattributes: 100%|██████████| 1.63k/1.63k [00:00<00:00, 8.25MB/s]
# slim-topics.gguf: 100%|██████████| 669M/669M [03:03<00:00, 3.64MB/s]
# Fetching 4 files: 100%|██████████| 4/4 [03:04<00:00, 46.10s/it]
# README.md: 100%|██████████| 1.73k/1.73k [00:00<00:00, 5.05MB/s]
#
# config.json: 100%|██████████| 7.53k/7.53k [00:00<00:00, 801kB/s]
# .gitattributes: 100%|██████████| 1.57k/1.57k [00:00<00:00, 7.29MB/s]
# Fetching 4 files:  25%|██▌       | 1/4 [00:01<00:05,  1.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# slim-ratings.gguf: 100%|██████████| 669M/669M [03:12<00:00, 3.48MB/s]
# Fetching 4 files: 100%|██████████| 4/4 [03:14<00:00, 48.56s/it]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
# README.md: 100%|██████████| 1.69k/1.69k [00:00<00:00, 779kB/s]
# config.json: 100%|██████████| 16.8k/16.8k [00:00<00:00, 3.55MB/s]
# .gitattributes: 100%|██████████| 1.57k/1.57k [00:00<00:00, 788kB/s]
# slim-nli.gguf: 100%|██████████| 669M/669M [04:14<00:00, 2.63MB/s]
# Fetching 4 files: 100%|██████████| 4/4 [04:15<00:00, 63.98s/it]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
# config.json: 100%|██████████| 5.77k/5.77k [00:00<00:00, 1.63MB/s]
# .gitattributes: 100%|██████████| 1.57k/1.57k [00:00<00:00, 441kB/s]
# README.md: 100%|██████████| 1.71k/1.71k [00:00<00:00, 525kB/s]
# slim-intent.gguf: 100%|██████████| 669M/669M [03:02<00:00, 3.66MB/s]
# Fetching 4 files: 100%|██████████| 4/4 [03:03<00:00, 45.90s/it]
# .gitattributes: 100%|██████████| 1.57k/1.57k [00:00<00:00, 6.13MB/s]
# Fetching 6 files:  17%|█▋        | 1/6 [00:00<00:02,  1.94it/s]
#
#
# README.md: 100%|██████████| 1.98k/1.98k [00:00<00:00, 807kB/s]
# config.json: 100%|██████████| 3.92k/3.92k [00:00<00:00, 2.41MB/s]
# customer_table.csv: 100%|██████████| 1.00k/1.00k [00:00<00:00, 124kB/s]
# library_table.csv: 100%|██████████| 317/317 [00:00<00:00, 883kB/s]
# slim-sql.gguf: 100%|██████████| 669M/669M [03:06<00:00, 3.59MB/s]
# Fetching 6 files: 100%|██████████| 6/6 [03:07<00:00, 31.19s/it]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
# .gitattributes: 100%|██████████| 1.62k/1.62k [00:00<00:00, 3.54MB/s]
# README.md: 100%|██████████| 1.50k/1.50k [00:00<00:00, 402kB/s]
# config.json: 100%|██████████| 247k/247k [00:00<00:00, 3.93MB/s]
# bling-answer.gguf: 100%|██████████| 669M/669M [03:06<00:00, 3.59MB/s]
# Fetching 4 files: 100%|██████████| 4/4 [03:07<00:00, 46.87s/it]
# .gitattributes: 100%|██████████| 1.63k/1.63k [00:00<00:00, 8.51MB/s]
# config.json: 100%|██████████| 15.1k/15.1k [00:00<00:00, 24.3MB/s]
#
# README.md: 100%|██████████| 1.74k/1.74k [00:00<00:00, 9.04MB/s]
# slim-category.gguf: 100%|██████████| 669M/669M [03:27<00:00, 3.22MB/s]
# Fetching 4 files: 100%|██████████| 4/4 [03:31<00:00, 52.76s/it]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
# .gitattributes: 100%|██████████| 1.57k/1.57k [00:00<00:00, 654kB/s]
# README.md: 100%|██████████| 1.70k/1.70k [00:00<00:00, 258kB/s]
# config.json: 100%|██████████| 15.0k/15.0k [00:00<00:00, 3.65MB/s]
# slim-tags.gguf: 100%|██████████| 669M/669M [03:08<00:00, 3.54MB/s]
# Fetching 4 files: 100%|██████████| 4/4 [03:09<00:00, 47.36s/it]
# Test:  slim-sentiment-tool
#
# update: context - test - 0 - Stocks rallied Friday even after the release of stronger-than-expected U.S. jobs data and a major increase in Treasury yields.  The Dow Jones Industrial Average gained 195.12 points, or 0.76%, to close at 31,419.58. The S&P 500 added 1.59% at 4,008.50. The tech-heavy Nasdaq Composite rose 1.35%, closing at 12,299.68. The U.S. economy added 438,000 jobs in August, the Labor Department said. Economists polled by Dow Jones expected 273,000 jobs. However, wages rose less than expected last month.  Stocks posted a stunning turnaround on Friday, after initially falling on the stronger-than-expected jobs report.
# update: 'llm_response' - test -  0 {'sentiment': ['positive']}
# tokenizer_config.json: 100%|██████████| 776/776 [00:00<00:00, 1.48MB/s]
# tokenizer.model: 100%|██████████| 500k/500k [00:00<00:00, 2.17MB/s]
# tokenizer.json: 100%|██████████| 1.84M/1.84M [00:00<00:00, 3.16MB/s]
# special_tokens_map.json: 100%|██████████| 414/414 [00:00<00:00, 1.11MB/s]
# update: red-yellow-green confidence -  {'sentiment': ['positive']}
# update: confidence score -  0.9579213228606186
# update: marker tokens -  [('positive', 1066, 0.9579213228606186), ('neutral', 17821, 0.02473497172992989), ('negative', 22198, 0.01564034220615836)]
# update: choices -  {'choice_1': ['pos', 0.9579213228606186, 1066], 'choice_2': ['neut', 0.02473497172992989, 17821], 'choice_3': ['negative', 0.01564034220615836, 22198]}
#
# update: context - test - 1 - The Nasdaq and the S&P 500 slid by 0.8% during their lowest points in the day.  Some noted it could be the softer wage number in the jobs report that made investors confirm their bearish stance. Others noted the pullback in yields from the day’s highs.  'We’re seeing a little bit of a give back in yields from where we were around 4.8%. 'We’ve had a lot of weakness in the market in recent weeks, and potentially some oversold conditions.'
# update: 'llm_response' - test -  1 {'sentiment': ['negative']}
# update: red-yellow-green confidence -  {'sentiment': ['negative']}
# update: confidence score -  0.4558080482551895
# update: marker tokens -  [('negative', 22198, 0.4558080482551895), ('neutral', 17821, 0.44972934535725845), ('positive', 1066, 0.09181370637684193)]
# update: choices -  {'choice_1': ['negative', 0.4558080482551895, 22198], 'choice_2': ['neut', 0.44972934535725845, 17821], 'choice_3': ['pos', 0.09181370637684193, 1066]}
#
# update: context - test - 2 - Nokia said it would cut up to 14,000 jobs as part of a cost cutting plan following third quarter earnings that plunged. The Finnish telecommunications giant said that it will reduce its cost base and increase operation efficiency to “address the challenging market environment. The substantial layoffs come after Nokia reported third-quarter net sales declined 20% year-on-year to 4.98 billion euros. Profit over the period plunged by 69% year-on-year to 133 million euros.
# update: 'llm_response' - test -  2 {'sentiment': ['negative']}
# update: red-yellow-green confidence -  {'sentiment': ['negative']}
# update: confidence score -  0.9708829889795899
# update: marker tokens -  [('negative', 22198, 0.9708829889795899), ('positive', 1066, 0.023771632860044065), ('neutral', 17821, 0.0035647877499572554)]
# update: choices -  {'choice_1': ['negative', 0.9708829889795899, 22198], 'choice_2': ['pos', 0.023771632860044065, 1066], 'choice_3': ['neut', 0.0035647877499572554, 17821]}
#
# update: context - test - 3 - Moody’s Investors Service lowered its ratings outlook on the United States’ government to negative from stable, pointing to rising risks to the nation’s fiscal strength.
# update: 'llm_response' - test -  3 {'sentiment': ['negative']}
# update: red-yellow-green confidence -  {'sentiment': ['negative']}
# update: confidence score -  0.8127705678186874
# update: marker tokens -  [('negative', 22198, 0.8127705678186874), ('neutral', 17821, 0.10079574199480838), ('positive', 1066, 0.08550785763510428)]
# update: choices -  {'choice_1': ['negative', 0.8127705678186874, 22198], 'choice_2': ['neut', 0.10079574199480838, 17821], 'choice_3': ['pos', 0.08550785763510428, 1066]}
#
# update: context - test - 4 - 'The world's most advanced AI models are coming together with the world's most universal user interface - natural language - to create a new era of computing,' said Satya Nadella, chairman and chief executive officer of Microsoft. 'Across the Microsoft Cloud, we are the platform of choice to help customers get the most value out of their digital spend and innovate for this next generation of AI.' 'Focused execution by our sales teams and partners in this dynamic environment resulted in Microsoft Cloud revenue of $28.5 billion, up 22% (up 25% in constant currency) year-over-year,' said Amy Hood, executive vice president and chief financial officer of Microsoft.
# update: 'llm_response' - test -  4 {'sentiment': ['positive']}
# update: red-yellow-green confidence -  {'sentiment': ['positive']}
# update: confidence score -  0.9879031339277443
# update: marker tokens -  [('positive', 1066, 0.9879031339277443), ('neutral', 17821, 0.011098917089281759), ('negative', 22198, 0.0006153144370410383)]
# update: choices -  {'choice_1': ['pos', 0.9879031339277443, 1066], 'choice_2': ['neut', 0.011098917089281759, 17821], 'choice_3': ['negative', 0.0006153144370410383, 22198]}
#
# update: context - test - 5 - Invoice DATE March 3, 2022	INVOICE NO 234	ABC Company 8675 River Run Road Marlington, CT 09392 INVOICE TO Delta Inc. 8723 Wilton Boulevard Los Angeles, CA HEBE HERACLES	LASER PRINTER	PAYMENT TERMS DUE DATE Due on Receipt May 3, 2022 QUANTITY DESCRIPTION UNIT PRICE LINE TOTAL 30 	Boxes of Printer Paper	$30	$900 10	Printer Cartridges	$75 $750 5	Laser printers	$500.00 $2500.00 Subtotal 4150.00 Sales Tax 10% Total 4565.00.
# Conclusion: Payment is due on May 3, 2022.
# update: 'llm_response' - test -  5 {'sentiment': ['neutral']}
# update: red-yellow-green confidence -  {'sentiment': ['neutral']}
# update: confidence score -  0.7417225063130681
# update: marker tokens -  [('neutral', 17821, 0.7417225063130681), ('positive', 1066, 0.1797342668778721), ('negative', 22198, 0.07754493049771456)]
# update: choices -  {'choice_1': ['neut', 0.7417225063130681, 17821], 'choice_2': ['pos', 0.1797342668778721, 1066], 'choice_3': ['negative', 0.07754493049771456, 22198]}
#
# update: context - test - 6 - THIS EXECUTIVE EMPLOYMENT AGREEMENT (this “Agreement”) is entered into this 2nd day of April, 2012, by and between Aphrodite Apollo (“Executive”) and TestCo Software, Inc. (the “Company” or “Employer”), and shall become effective upon Executive’s commencement of employment (the “Effective Date”) which is expected to commence on April 16, 2012. The Company and Executive agree that unless Executive has commenced employment with the Company as of April 16, 2012 (or such later date as agreed by each of the Company and Executive) this Agreement shall be null and void and of no further effect.
# update: 'llm_response' - test -  6 {'sentiment': ['neutral']}
# update: red-yellow-green confidence -  {'sentiment': ['neutral']}
# update: confidence score -  0.692754386424117
# update: marker tokens -  [('neutral', 17821, 0.692754386424117), ('negative', 22198, 0.2360815943416135), ('positive', 1066, 0.0682455004898731)]
# update: choices -  {'choice_1': ['neut', 0.692754386424117, 17821], 'choice_2': ['negative', 0.2360815943416135, 22198], 'choice_3': ['pos', 0.0682455004898731, 1066]}
#
# update: context - test - 7 - This is the best electronics product I have ever used - the packaging, technology, and overall quality are exceptional, and the price is pretty good too.
# update: 'llm_response' - test -  7 {'sentiment': ['positive']}
# update: red-yellow-green confidence -  {'sentiment': ['positive']}
# update: confidence score -  0.9915813490169639
# update: marker tokens -  [('positive', 1066, 0.9915813490169639), ('neutral', 17821, 0.004961465687144066), ('negative', 22198, 0.002934669288720324)]
# update: choices -  {'choice_1': ['pos', 0.9915813490169639, 1066], 'choice_2': ['neut', 0.004961465687144066, 17821], 'choice_3': ['negative', 0.002934669288720324, 22198]}
#
# update: context - test - 8 - This is the third time I am calling to try to get support to resolve my issue. I am getting frustrated that we can not find any solution to my problem.
# update: 'llm_response' - test -  8 {'sentiment': ['negative']}
# update: red-yellow-green confidence -  {'sentiment': ['negative']}
# update: confidence score -  0.9103383625255279
# update: marker tokens -  [('negative', 22198, 0.9103383625255279), ('neutral', 17821, 0.07314240368141542), ('positive', 1066, 0.015499811262213524)]
# update: choices -  {'choice_1': ['negative', 0.9103383625255279, 22198], 'choice_2': ['neut', 0.07314240368141542, 17821], 'choice_3': ['pos', 0.015499811262213524, 1066]}
#
# update: context - test - 9 - I have a hard time finding a complaint with the service, which was all around very good, and delivered up to my expectations.
# update: 'llm_response' - test -  9 {'sentiment': ['positive']}
# update: red-yellow-green confidence -  {'sentiment': ['positive']}
# update: confidence score -  0.9937772690209103
# update: marker tokens -  [('positive', 1066, 0.9937772690209103), ('neutral', 17821, 0.002824951667296088), ('negative', 22198, 0.002763087862892464)]
# update: choices -  {'choice_1': ['pos', 0.9937772690209103, 1066], 'choice_2': ['neut', 0.002824951667296088, 17821], 'choice_3': ['negative', 0.002763087862892464, 22198]}
#
# update: context - test - 10 - The Nasdaq Composite and the S&P 500 each rose for the fifth day in a row Wednesday. The S&P increased by a minuscule 0.08% but was still able to secure a new all-time closing record. The Nasdaq was led by a broader tech rally and finished the day 0.36% higher. The Dow missed out on the day’s rally and was dragged down by declines of more than 2% in Verizon and 3M, which each reported earnings on Tuesday. Netflix, meanwhile, soared after its Tuesday earnings report and finished the day with gains of more than 10%. Follow live market updates.
# update: 'llm_response' - test -  10 {'sentiment': ['positive']}
# update: red-yellow-green confidence -  {'sentiment': ['positive']}
# update: confidence score -  0.9717650202723385
# update: marker tokens -  [('positive', 1066, 0.9717650202723385), ('neutral', 17821, 0.021865775810310312), ('negative', 22198, 0.005010682539103232)]
# update: choices -  {'choice_1': ['pos', 0.9717650202723385, 1066], 'choice_2': ['neut', 0.021865775810310312, 17821], 'choice_3': ['negative', 0.005010682539103232, 22198]}
#
# update: context - test - 11 - Tesla stock fell 8% in premarket trading after reporting fourth-quarter revenue and profit that missed analysts’ estimates. The electric vehicle company also warned that vehicle volume growth in 2024 'may be notably lower' than last year’s growth rate. Automotive revenue, meanwhile, increased just 1% from a year earlier, partly because the EVs were selling for less than they had in the past. Tesla implemented steep price cuts in the second half of the year around the world. In a Wednesday presentation, the company warned investors that it’s 'currently between two major growth waves.'
# update: 'llm_response' - test -  11 {'sentiment': ['negative']}
# update: red-yellow-green confidence -  {'sentiment': ['negative']}
# update: confidence score -  0.9290429590411214
# update: marker tokens -  [('negative', 22198, 0.9290429590411214), ('positive', 1066, 0.03514698145721787), ('neutral', 17821, 0.0347414823399976)]
# update: choices -  {'choice_1': ['negative', 0.9290429590411214, 22198], 'choice_2': ['pos', 0.03514698145721787, 1066], 'choice_3': ['neut', 0.0347414823399976, 17821]}
#
# update: context - test - 12 - Alaska Airlines said the grounding of Boeing 737 Max 9 planes will cost the company $150 million. The Max 9s were grounded weeks ago after a door plug blew out during an Alaska Airlines flight while the plane was 16,000 feet above the ground, leaving a hole in the side of the aircraft. The airline said Thursday morning in a disclosure that it had been expecting to grow its capacity from 3% to 5% this year, but it now expects the growth to be “at or below the lower end of this range.” Alaska Airline’s announcement came on the heels of the Federal Aviation Administration late Wednesday clearing a path for the planes to return to service but halting Boeing’s plans to increase production of them.
# update: 'llm_response' - test -  12 {'sentiment': ['negative']}
# update: red-yellow-green confidence -  {'sentiment': ['negative']}
# update: confidence score -  0.7835242192897832
# update: marker tokens -  [('negative', 22198, 0.7835242192897832), ('neutral', 17821, 0.12346466331481763), ('positive', 1066, 0.09154767128977669)]
# update: choices -  {'choice_1': ['negative', 0.7835242192897832, 22198], 'choice_2': ['neut', 0.12346466331481763, 17821], 'choice_3': ['pos', 0.09154767128977669, 1066]}
#
# update: context - test - 13 - “I guess we are going to war again?” legal journalist Molly Quell wrote on X, formerly known as Twitter. “What is going on over there?” asked British comedian Matt Green.  Francl, a chemistry professor at Bryn Mawr College in Pennsylvania, defended her seemingly radical idea to CNN affiliate ITV News, claiming: “It turns out that a tiny amount of salt, not enough to even taste, blocks the perception of bitterness.”  As transatlantic tensions reached a boiling point, the US Embassy in the UK intervened to distance themselves from the seemingly extremist idea, dunking the professor back into hot water.  “We cannot stand idly by as such an outrageous proposal threatens the very foundation of our Special Relationship,” the embassy wrote in a viral X post.  “We want to ensure the good people of the UK that the unthinkable notion of adding salt to Britain’s national drink is not official Unites States policy. And never will be,” it added.  Francl also found little sympathy in the British press, which took her suggestion with more than a pinch of salt.
# update: 'llm_response' - test -  13 {'sentiment': ['negative']}
# update: red-yellow-green confidence -  {'sentiment': ['negative']}
# update: confidence score -  0.6438403556875512
# update: marker tokens -  [('negative', 22198, 0.6438403556875512), ('neutral', 17821, 0.2503402847340986), ('positive', 1066, 0.1046886958204349)]
# update: choices -  {'choice_1': ['negative', 0.6438403556875512, 22198], 'choice_2': ['neut', 0.2503402847340986, 17821], 'choice_3': ['pos', 0.1046886958204349, 1066]}
#
# update: context - test - 14 - The command string can include multiple SQL commands (separated by semicolons). Multiple queries sent in a single PQexec call are processed in a single transaction, unless there are explicit BEGIN/COMMIT commands included in the query string to divide it into multiple transactions. (See Section 55.2.2.1 for more details about how the server handles multi-query strings.) Note however that the returned PGresult structure describes only the result of the last command executed from the string. Should one of the commands fail, processing of the string stops with it and the returned PGresult describes the error condition.
# update: 'llm_response' - test -  14 {'sentiment': ['neutral']}
# update: red-yellow-green confidence -  {'sentiment': ['neutral']}
# update: confidence score -  0.7525542613464643
# update: marker tokens -  [('neutral', 17821, 0.7525542613464643), ('negative', 22198, 0.17965032402661532), ('positive', 1066, 0.06703343648690038)]
# update: choices -  {'choice_1': ['neut', 0.7525542613464643, 17821], 'choice_2': ['negative', 0.17965032402661532, 22198], 'choice_3': ['pos', 0.06703343648690038, 1066]}
#
# update: context - test - 15 - Haley looks ahead to South Carolina: Nikki Haley insists she plans to stay in the GOP race and compete in South Carolina's February 24 primary. What’s not clear, though, is where Haley could notch a victory. She isn’t participating in the Nevada caucuses February 8 and polls show Trump has a big lead lead in South Carolina.
# update: 'llm_response' - test -  15 {'sentiment': ['neutral']}
# update: red-yellow-green confidence -  {'sentiment': ['neutral']}
# update: confidence score -  0.41103260864232777
# update: marker tokens -  [('neutral', 17821, 0.41103260864232777), ('positive', 1066, 0.3076948110195482), ('negative', 22198, 0.2794655041714802)]
# update: choices -  {'choice_1': ['neut', 0.41103260864232777, 17821], 'choice_2': ['pos', 0.3076948110195482, 1066], 'choice_3': ['negative', 0.2794655041714802, 22198]}
#
# update: context - test - 16 - The US economy remained shockingly robust in the fourth quarter to close out a remarkably strong 2023 as consumers and businesses continued to spend. Gross domestic product, a measure of all the services and goods and produced, rose at a seasonally adjusted, annualized 3.3% rate from October through December, the Commerce Department reported Thursday.  That was slower than the 4.9% rate from July through September, when American consumers splashed out on services and goods. Growth in 2023 overall registered at a robust 2.5% rate.
# update: 'llm_response' - test -  16 {'sentiment': ['positive']}
# update: red-yellow-green confidence -  {'sentiment': ['positive']}
# update: confidence score -  0.9898098889399012
# update: marker tokens -  [('positive', 1066, 0.9898098889399012), ('negative', 22198, 0.005256374085363646), ('neutral', 17821, 0.003962259114060087)]
# update: choices -  {'choice_1': ['pos', 0.9898098889399012, 1066], 'choice_2': ['negative', 0.005256374085363646, 22198], 'choice_3': ['neut', 0.003962259114060087, 17821]}
#
# update: context - test - 17 - Sales problems in China. Patent lawsuits in the US. Behind in generative AI. It’s only a few weeks into 2024, and Apple’s year ahead is paved with trouble.  The tech giant’s barrage of challenges impact many parts of its overall business. Just last week, Microsoft took Apple’s spot as the most valuable publicly traded company, after trailing behind the iPhone maker for the better part of the last decade. Microsoft’s stock climb is due largely to its early and sweeping bets on generative artificial intelligence, an area in which Apple has largely remained mum.
# update: 'llm_response' - test -  17 {'sentiment': ['negative']}
# update: red-yellow-green confidence -  {'sentiment': ['negative']}
# update: confidence score -  0.7334659986861468
# update: marker tokens -  [('negative', 22198, 0.7334659986861468), ('positive', 1066, 0.1901724972763341), ('neutral', 17821, 0.07323347277286682)]
# update: choices -  {'choice_1': ['negative', 0.7334659986861468, 22198], 'choice_2': ['pos', 0.1901724972763341, 1066], 'choice_3': ['neut', 0.07323347277286682, 17821]}
#
# update: context - test - 18 - 'Being Apple, which is still the largest company in the world by market cap, I’m sure it will do all it can to minimize the impact of these problem areas,' said David McQueen, an analyst at ABI Research. 'It will still have an extremely loyal base of users so that its brand value and recognition, and quality are not compromised.'
# update: 'llm_response' - test -  18 {'sentiment': ['positive']}
# update: red-yellow-green confidence -  {'sentiment': ['positive']}
# update: confidence score -  0.8462695346713058
# update: marker tokens -  [('positive', 1066, 0.8462695346713058), ('neutral', 17821, 0.13069077838448706), ('negative', 22198, 0.021706562651583952)]
# update: choices -  {'choice_1': ['pos', 0.8462695346713058, 1066], 'choice_2': ['neut', 0.13069077838448706, 17821], 'choice_3': ['negative', 0.021706562651583952, 22198]}
#
# update: context - test - 19 - As Kate Middleton recovers following abdominal surgery, there is confidence in her resilience. It does sound serious with the length of time [she’s taking]. But she is in great hands and will have lots of care and support at home and is a fit young woman,” a source close to the royal household tells PEOPLE exclusively in this week’s issue. “I am sure she will bounce back.” The Princess of Wales, 42, is embarking on a long recovery after having “planned abdominal surgery” at the private London Clinic on Jan. 16, which was announced by Kensington Palace the following day. The statement said that Princess Kate would remain hospitalized for “10 to 14 days, before returning home to continue her recovery” and that it would be unlikely for her to “return to public duties until after Easter.”
# update: 'llm_response' - test -  19 {'sentiment': ['positive']}
# update: red-yellow-green confidence -  {'sentiment': ['positive']}
# update: confidence score -  0.8559289597116925
# update: marker tokens -  [('positive', 1066, 0.8559289597116925), ('neutral', 17821, 0.13006843285104733), ('negative', 22198, 0.012600384113598189)]
# update: choices -  {'choice_1': ['pos', 0.8559289597116925, 1066], 'choice_2': ['neut', 0.13006843285104733, 17821], 'choice_3': ['negative', 0.012600384113598189, 22198]}
# 0
